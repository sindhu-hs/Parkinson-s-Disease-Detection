# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#PATH PROCESS
import os
import os.path
from pathlib import Path
import glob

# %%
#IMAGE PROCESS
from PIL import Image
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2

# %%
#SCALER & TRANSFORMATION
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras import regularizers
from sklearn.preprocessing import LabelEncoder

# %%
#ACCURACY CONTROL
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score

# %%
#OPTIMIZER
from keras.optimizers import RMSprop,Adam,Optimizer,Optimizer

# %%
#MODEL LAYERS
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization,MaxPooling2D,BatchNormalization,\
                        Permute, TimeDistributed, Bidirectional,GRU, SimpleRNN, LSTM, GlobalAveragePooling2D, SeparableConv2D
from keras import models
from keras import layers
import tensorflow as tf
from keras.applications import VGG16,VGG19,inception_v3
from keras import backend as K
from keras.utils import plot_model

# %%
#TENSORFLOW
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l2

# %%
#IGNORING WARNINGS
from warnings import filterwarnings
filterwarnings("ignore",category=DeprecationWarning)
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)

# %%
Spiral_Train_Path = Path(r"D:\NIT Trichy\PD_detection\spiral\training")
Spiral_Test_Path = Path(r"D:\NIT Trichy\PD_detection\spiral\testing")
print(Spiral_Train_Path)
print(Spiral_Test_Path)
# Out:
# D:\NIT Trichy\PD_detection\spiral\training
# D:\NIT Trichy\PD_detection\spiral\testing

# %%
Spiral_Train_PNG_Path = list(Spiral_Train_Path.glob(r"*/*.png"))
Spiral_Test_PNG_Path = list(Spiral_Test_Path.glob(r"*/*.png"))
print(Spiral_Train_PNG_Path)
print("---------------")
print(Spiral_Test_PNG_Path)
# Out:
# [WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V01HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V01HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V02HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V02HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V03HE2.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V03HE3.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V04HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V04HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V05HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V05HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V06HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V06HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V07HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V07HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V08HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V08HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V09HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V09HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V10HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V10HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V11HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V11HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V12HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V12HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V12HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE04.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE05.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE06.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE07.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE08.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE09.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE10.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/healthy/V55HE11.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V01PE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V01PE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V02PE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V02PE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V03PE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V03PE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V03PE05.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V03PE06.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V03PE08.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V03PE09.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V04PE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V04PE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V05PE02.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/training/parkinson/V05PE03.png'), WindowsPath('D:/NIT Tri ...
# ---------------
# [WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V01HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V02HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V03HE1.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V04HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V05HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V06HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V07HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V08HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V09HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V10HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V11HE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V55HE12.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V55HE13.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V55HE14.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/healthy/V55HE15.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V01PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V02PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V03PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V03PE04.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V03PE07.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V04PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V05PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V06PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V07PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V08PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V09PE01.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V10PE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V11PE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V14PE03.png'), WindowsPath('D:/NIT Trichy/PD_detection/spiral/testing/parkinson/V15PE01.png')]

# %%
Spiral_Train_PNG_Labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],Spiral_Train_PNG_Path))
Spiral_Test_PNG_Labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],Spiral_Test_PNG_Path))
print(Spiral_Train_PNG_Labels)
print("------------")
print(Spiral_Test_PNG_Labels)
# Out:
# ['healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson']
# ------------
# ['healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson']

# %%
Spiral_Train_PNG_Path_Series = pd.Series(Spiral_Train_PNG_Path,name="PNG").astype(str)
Spiral_Train_PNG_Labels_Series = pd.Series(Spiral_Train_PNG_Labels,name="CATEGORY")
print(Spiral_Train_PNG_Path_Series)
print("------------")
print(Spiral_Train_PNG_Labels_Series)
# Out:
# 0     D:\NIT Trichy\PD_detection\spiral\training\hea...
# 1     D:\NIT Trichy\PD_detection\spiral\training\hea...
# 2     D:\NIT Trichy\PD_detection\spiral\training\hea...
# 3     D:\NIT Trichy\PD_detection\spiral\training\hea...
# 4     D:\NIT Trichy\PD_detection\spiral\training\hea...
#                             ...
# 67    D:\NIT Trichy\PD_detection\spiral\training\par...
# 68    D:\NIT Trichy\PD_detection\spiral\training\par...
# 69    D:\NIT Trichy\PD_detection\spiral\training\par...
# 70    D:\NIT Trichy\PD_detection\spiral\training\par...
# 71    D:\NIT Trichy\PD_detection\spiral\training\par...
# Name: PNG, Length: 72, dtype: object
# ------------
# 0       healthy
# 1       healthy
# 2       healthy
# 3       healthy
# 4       healthy
#         ...
# 67    parkinson
# 68    parkinson
# 69    parkinson
# 70    parkinson
# 71    parkinson
# Name: CATEGORY, Length: 72, dtype: object

# %%
Spiral_Test_PNG_Path_Series = pd.Series(Spiral_Test_PNG_Path,name="PNG").astype(str)
Spiral_Test_PNG_Labels_Series = pd.Series(Spiral_Test_PNG_Labels,name="CATEGORY")

# %%
Main_Spiral_Train_Data = pd.concat([Spiral_Train_PNG_Path_Series,Spiral_Train_PNG_Labels_Series],axis=1)
print(Main_Spiral_Train_Data)
# Out:
#                                                   PNG   CATEGORY
# 0   D:\NIT Trichy\PD_detection\spiral\training\hea...    healthy
# 1   D:\NIT Trichy\PD_detection\spiral\training\hea...    healthy
# 2   D:\NIT Trichy\PD_detection\spiral\training\hea...    healthy
# 3   D:\NIT Trichy\PD_detection\spiral\training\hea...    healthy
# 4   D:\NIT Trichy\PD_detection\spiral\training\hea...    healthy
# ..                                                ...        ...
# 67  D:\NIT Trichy\PD_detection\spiral\training\par...  parkinson
# 68  D:\NIT Trichy\PD_detection\spiral\training\par...  parkinson
# 69  D:\NIT Trichy\PD_detection\spiral\training\par...  parkinson
# 70  D:\NIT Trichy\PD_detection\spiral\training\par...  parkinson
# 71  D:\NIT Trichy\PD_detection\spiral\training\par...  parkinson
#
# [72 rows x 2 columns]

# %%
Main_Spiral_Test_Data = pd.concat([Spiral_Test_PNG_Path_Series,Spiral_Test_PNG_Labels_Series],axis=1)

# %%
Main_Spiral_Train_Data = Main_Spiral_Train_Data.sample(frac=1).reset_index(drop=True)
Main_Spiral_Test_Data = Main_Spiral_Test_Data.sample(frac=1).reset_index(drop=True)
print(Main_Spiral_Test_Data)
# Out:
#                                                   PNG   CATEGORY
# 0   D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 1   D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 2   D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 3   D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 4   D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 5   D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 6   D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 7   D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 8   D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 9   D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 10  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 11  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 12  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 13  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 14  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 15  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 16  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 17  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 18  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 19  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 20  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 21  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 22  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 23  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 24  D:\NIT Trichy\PD_detection\spiral\testing\heal...    healthy
# 25  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 26  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 27  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 28  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson
# 29  D:\NIT Trichy\PD_detection\spiral\testing\park...  parkinson

# %%
x_train = []
for i in range(len(Main_Spiral_Train_Data)):
    img = cv2.imread(Main_Spiral_Train_Data["PNG"][i])
    x_train.append(np.array(img))

# %%
x_test= []
for i in range(len(Main_Spiral_Test_Data)):
    img = cv2.imread(Main_Spiral_Test_Data["PNG"][i])
    x_test.append(np.array(img))

# %%
train_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_train)
y = list(Main_Spiral_Train_Data["CATEGORY"])

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=360, 
                                    width_shift_range=0.0, 
                                    height_shift_range=0.0, 
#                                     brightness_range=[0.5, 1.5],
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_test)
y = list(Main_Spiral_Test_Data["CATEGORY"])

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 5040
# 5040
# 5112
# 5112
# 600
# 600
# 630
# 630

# %%
# print(y_test)
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_train) if v=='healthy']
img_healthy = x_train[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_train) if v=='parkinson']
img_parkinson = x_train[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_test) if v=='healthy']
img_healthy = x_test[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Spiral Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_test) if v=='parkinson']
img_parkinson = x_test[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Spiral Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %%
for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_train[i] = img
    
for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_test[i] = img

x_train = np.array(x_train)
x_test = np.array(x_test)

x_train = x_train/255.0
x_test = x_test/255.0

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(y_train.shape)

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(y_test.shape)
# Out:
# (5112,)
# (630,)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (5112, 128, 128, 1)
# (5112, 2)
# (630, 128, 128, 1)
# (630, 2)

# %%
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))

    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))
    
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))    
    
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))
    
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  fc1 (Dense)                 (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  fc3 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 238,146
# Trainable params: 238,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train, y_train, batch_size=10, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 512/512 [==============================] - 72s 140ms/step - loss: 0.8266 - accuracy: 0.5049 - val_loss: 0.8030 - val_accuracy: 0.5000
# Epoch 2/70
# 512/512 [==============================] - 75s 146ms/step - loss: 0.7904 - accuracy: 0.4947 - val_loss: 0.7795 - val_accuracy: 0.5000
# Epoch 3/70
# 512/512 [==============================] - 73s 142ms/step - loss: 0.7721 - accuracy: 0.4951 - val_loss: 0.7656 - val_accuracy: 0.4889
# Epoch 4/70
# 512/512 [==============================] - 72s 141ms/step - loss: 0.7604 - accuracy: 0.5000 - val_loss: 0.7553 - val_accuracy: 0.5000
# Epoch 5/70
# 512/512 [==============================] - 71s 138ms/step - loss: 0.7511 - accuracy: 0.4982 - val_loss: 0.7469 - val_accuracy: 0.5000
# Epoch 6/70
# 512/512 [==============================] - 71s 139ms/step - loss: 0.7433 - accuracy: 0.5108 - val_loss: 0.7397 - val_accuracy: 0.5000
# Epoch 7/70
# 512/512 [==============================] - 72s 141ms/step - loss: 0.7365 - accuracy: 0.5047 - val_loss: 0.7339 - val_accuracy: 0.4794
# Epoch 8/70
# 512/512 [==============================] - 71s 139ms/step - loss: 0.7308 - accuracy: 0.5037 - val_loss: 0.7283 - val_accuracy: 0.4984
# Epoch 9/70
# 512/512 [==============================] - 70s 137ms/step - loss: 0.7253 - accuracy: 0.5166 - val_loss: 0.7232 - val_accuracy: 0.5000
# Epoch 10/70
# 512/512 [==============================] - 62s 121ms/step - loss: 0.7207 - accuracy: 0.5246 - val_loss: 0.7196 - val_accuracy: 0.5000
# Epoch 11/70
# 512/512 [==============================] - 43s 84ms/step - loss: 0.7158 - accuracy: 0.5354 - val_loss: 0.7157 - val_accuracy: 0.5381
# Epoch 12/70
# 512/512 [==============================] - 43s 84ms/step - loss: 0.7109 - accuracy: 0.5542 - val_loss: 0.7120 - val_accuracy: 0.5794
# Epoch 13/70
# 512/512 [==============================] - 44s 85ms/step - loss: 0.7017 - accuracy: 0.5784 - val_loss: 0.7045 - val_accuracy: 0.6095
# Epoch 14/70
# 512/512 [==============================] - 51s 100ms/step - loss: 0.6732 - accuracy: 0.6704 - val_loss: 0.6671 - val_accuracy: 0.6429
# Epoch 15/70
# 512/512 [==============================] - 45s 88ms/step - loss: 0.6239 - accuracy: 0.7273 - val_loss: 0.5860 - val_accuracy: 0.7825
# Epoch 16/70
# 512/512 [==============================] - 44s 86ms/step - loss: 0.5817 - accuracy: 0.7478 - val_loss: 0.5665 - val_accuracy: 0.7460
# Epoch 17/70
# 512/512 [==============================] - 47s 92ms/step - loss: 0.5471 - accuracy: 0.7860 - val_loss: 0.4886 - val_accuracy: 0.8159
# Epoch 18/70
# 512/512 [==============================] - 45s 88ms/step - loss: 0.5140 - accuracy: 0.8058 - val_loss: 0.4611 - val_accuracy: 0.8206
# Epoch 19/70
# 512/512 [==============================] - 45s 88ms/step - loss: 0.4893 - accuracy: 0.8065 - val_loss: 0.4205 - val_accuracy: 0.8365
# Epoch 20/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.4649 - accuracy: 0.8308 - val_loss: 0.4160 - val_accuracy: 0.8317
# Epoch 21/70
# 512/512 [==============================] - 46s 89ms/step - loss: 0.4497 - accuracy: 0.8363 - val_loss: 0.4103 - val_accuracy: 0.8476
# Epoch 22/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4223 - accuracy: 0.8537 - val_loss: 0.3621 - val_accuracy: 0.8587
# Epoch 23/70
# 512/512 [==============================] - 44s 86ms/step - loss: 0.4059 - accuracy: 0.8545 - val_loss: 0.3653 - val_accuracy: 0.8762
# Epoch 24/70
# 512/512 [==============================] - 48s 95ms/step - loss: 0.3936 - accuracy: 0.8613 - val_loss: 0.3551 - val_accuracy: 0.8667
# Epoch 25/70
# 512/512 [==============================] - 53s 104ms/step - loss: 0.3685 - accuracy: 0.8695 - val_loss: 0.3617 - val_accuracy: 0.8603
# Epoch 26/70
# 512/512 [==============================] - 49s 95ms/step - loss: 0.3554 - accuracy: 0.8826 - val_loss: 0.3631 - val_accuracy: 0.8587
# Epoch 27/70
# 512/512 [==============================] - 50s 98ms/step - loss: 0.3506 - accuracy: 0.8846 - val_loss: 0.4900 - val_accuracy: 0.7937
# Epoch 28/70
# 512/512 [==============================] - 49s 96ms/step - loss: 0.3394 - accuracy: 0.8885 - val_loss: 0.3380 - val_accuracy: 0.8841
# Epoch 29/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.3199 - accuracy: 0.8963 - val_loss: 0.3745 - val_accuracy: 0.8460
# Epoch 30/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.3131 - accuracy: 0.8963 - val_loss: 0.3361 - val_accuracy: 0.8905
# Epoch 31/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.2896 - accuracy: 0.9063 - val_loss: 0.3717 - val_accuracy: 0.8603
# Epoch 32/70
# 512/512 [==============================] - 45s 88ms/step - loss: 0.2920 - accuracy: 0.9073 - val_loss: 0.3835 - val_accuracy: 0.8540
# Epoch 33/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.2810 - accuracy: 0.9145 - val_loss: 0.3290 - val_accuracy: 0.8905
# Epoch 34/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.2721 - accuracy: 0.9180 - val_loss: 0.3138 - val_accuracy: 0.8857
# Epoch 35/70
# 512/512 [==============================] - 44s 86ms/step - loss: 0.2586 - accuracy: 0.9264 - val_loss: 0.4477 - val_accuracy: 0.8381
# Epoch 36/70
# 512/512 [==============================] - 46s 89ms/step - loss: 0.2504 - accuracy: 0.9284 - val_loss: 0.3351 - val_accuracy: 0.8952
# Epoch 37/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.2477 - accuracy: 0.9278 - val_loss: 0.3316 - val_accuracy: 0.8984
# Epoch 38/70
# 512/512 [==============================] - 51s 99ms/step - loss: 0.2358 - accuracy: 0.9315 - val_loss: 0.3249 - val_accuracy: 0.8905
# Epoch 39/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.2273 - accuracy: 0.9354 - val_loss: 0.3360 - val_accuracy: 0.8968
# Epoch 40/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.2220 - accuracy: 0.9392 - val_loss: 0.3604 - val_accuracy: 0.8873
# Epoch 41/70
# 512/512 [==============================] - 46s 89ms/step - loss: 0.2081 - accuracy: 0.9429 - val_loss: 0.3371 - val_accuracy: 0.9016
# Epoch 42/70
# 512/512 [==============================] - 49s 96ms/step - loss: 0.2195 - accuracy: 0.9353 - val_loss: 0.3194 - val_accuracy: 0.9175
# Epoch 43/70
# 512/512 [==============================] - 47s 91ms/step - loss: 0.1964 - accuracy: 0.9478 - val_loss: 0.3455 - val_accuracy: 0.9095
# Epoch 44/70
# 512/512 [==============================] - 49s 96ms/step - loss: 0.1914 - accuracy: 0.9487 - val_loss: 0.3620 - val_accuracy: 0.8905
# Epoch 45/70
# 512/512 [==============================] - 48s 95ms/step - loss: 0.1869 - accuracy: 0.9513 - val_loss: 0.3628 - val_accuracy: 0.8889
# Epoch 46/70
# 512/512 [==============================] - 49s 95ms/step - loss: 0.1838 - accuracy: 0.9517 - val_loss: 0.3413 - val_accuracy: 0.9222
# Epoch 47/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.1742 - accuracy: 0.9542 - val_loss: 0.3222 - val_accuracy: 0.9175
# Epoch 48/70
# 512/512 [==============================] - 49s 96ms/step - loss: 0.1557 - accuracy: 0.9621 - val_loss: 0.3163 - val_accuracy: 0.9222
# Epoch 49/70
# 512/512 [==============================] - 45s 88ms/step - loss: 0.1667 - accuracy: 0.9558 - val_loss: 0.3182 - val_accuracy: 0.9238
# Epoch 50/70
# 512/512 [==============================] - 45s 87ms/step - loss: 0.1627 - accuracy: 0.9601 - val_loss: 0.3245 - val_accuracy: 0.9095
# Epoch 51/70
# 512/512 [==============================] - 49s 95ms/step - loss: 0.1543 - accuracy: 0.9613 - val_loss: 0.3735 - val_accuracy: 0.9063
# Epoch 52/70
# 512/512 [==============================] - 48s 94ms/step - loss: 0.1483 - accuracy: 0.9646 - val_loss: 0.3367 - val_accuracy: 0.9206
# Epoch 53/70
# 512/512 [==============================] - 46s 89ms/step - loss: 0.1380 - accuracy: 0.9687 - val_loss: 0.3463 - val_accuracy: 0.9206
# Epoch 54/70
# 512/512 [==============================] - 46s 91ms/step - loss: 0.1365 - accuracy: 0.9660 - val_loss: 0.3967 - val_accuracy: 0.8841
# Epoch 55/70
# 512/512 [==============================] - 44s 87ms/step - loss: 0.1414 - accuracy: 0.9664 - val_loss: 0.3486 - val_accuracy: 0.9222
# Epoch 56/70
# 512/512 [==============================] - 51s 100ms/step - loss: 0.1315 - accuracy: 0.9705 - val_loss: 0.3506 - val_accuracy: 0.9032
# Epoch 57/70
# 512/512 [==============================] - 52s 101ms/step - loss: 0.1326 - accuracy: 0.9697 - val_loss: 0.3777 - val_accuracy: 0.8937
# Epoch 58/70
# 512/512 [==============================] - 52s 102ms/step - loss: 0.1149 - accuracy: 0.9757 - val_loss: 0.3600 - val_accuracy: 0.9175
# Epoch 59/70
# 512/512 [==============================] - 49s 95ms/step - loss: 0.1172 - accuracy: 0.9722 - val_loss: 0.3683 - val_accuracy: 0.9222
# Epoch 60/70
# 512/512 [==============================] - 48s 94ms/step - loss: 0.1096 - accuracy: 0.9777 - val_loss: 0.3551 - val_accuracy: 0.9222
# Epoch 61/70
# 512/512 [==============================] - 48s 94ms/step - loss: 0.1123 - accuracy: 0.9777 - val_loss: 0.3907 - val_accuracy: 0.9190
# Epoch 62/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.1109 - accuracy: 0.9734 - val_loss: 0.4963 - val_accuracy: 0.8651
# Epoch 63/70
# 512/512 [==============================] - 49s 95ms/step - loss: 0.1099 - accuracy: 0.9755 - val_loss: 0.3629 - val_accuracy: 0.9222
# Epoch 64/70
# 512/512 [==============================] - 47s 91ms/step - loss: 0.1022 - accuracy: 0.9791 - val_loss: 0.3963 - val_accuracy: 0.9159
# Epoch 65/70
# 512/512 [==============================] - 46s 89ms/step - loss: 0.1035 - accuracy: 0.9797 - val_loss: 0.3821 - val_accuracy: 0.9159
# Epoch 66/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.1019 - accuracy: 0.9781 - val_loss: 0.6900 - val_accuracy: 0.8159
# Epoch 67/70
# 512/512 [==============================] - 48s 94ms/step - loss: 0.1064 - accuracy: 0.9775 - val_loss: 0.4554 - val_accuracy: 0.8873
# Epoch 68/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.0995 - accuracy: 0.9800 - val_loss: 0.4598 - val_accuracy: 0.8841
# Epoch 69/70
# 512/512 [==============================] - 48s 93ms/step - loss: 0.0902 - accuracy: 0.9838 - val_loss: 0.3879 - val_accuracy: 0.9254
# Epoch 70/70
# 512/512 [==============================] - 47s 92ms/step - loss: 0.0937 - accuracy: 0.9830 - val_loss: 0.3809 - val_accuracy: 0.9270

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 20/20 [==============================] - 1s 63ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92       315
#            1       0.90      0.97      0.93       315
#
#     accuracy                           0.93       630
#    macro avg       0.93      0.93      0.93       630
# weighted avg       0.93      0.93      0.93       630

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <AxesSubplot:>

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread(r'D:\NIT Trichy\PD_detection\spiral\testing\healthy\V09HE01.png')
image_parkinson = cv2.imread(r'D:\NIT Trichy\PD_detection\spiral\testing\parkinson\V08PE01.png')

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)
print(ypred_healthy)
# Out:
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 29ms/step
# [[1. 0.]]

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()

# %%
# serialize model to JSON
model_json = model.to_json()
with open("SpiralModel.json", "w") as json_file:
    json_file.write(model_json)

# %%
# serialize weights to HDF5
model.save_weights("SpiralModel.h5py")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.preprocessing import image
from keras.models import model_from_json
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import json
import tensorflow as tf

json_file = open('SpiralModel.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("SpiralModel.h5py")

print("Loaded model from disk")
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread(r"D:\NIT Trichy\PD_detection\spiral\testing\healthy\V04HE01.png")
image_parkinson = cv2.imread(r"D:\NIT Trichy\PD_detection\spiral\testing\parkinson\V01PE01.png")

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

ypred_healthy = loaded_model.predict(image_healthy)
ypred_parkinson = loaded_model.predict(image_parkinson)

figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
# Out:
# Loaded model from disk
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

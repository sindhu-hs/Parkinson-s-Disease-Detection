# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#PATH PROCESS
import os
import os.path
from pathlib import Path
import glob

# %%
#IMAGE PROCESS
from PIL import Image
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2

# %%
#SCALER & TRANSFORMATION
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from keras import regularizers
from sklearn.preprocessing import LabelEncoder

# %%
#ACCURACY CONTROL
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score

# %%
#OPTIMIZER
from keras.optimizers import RMSprop,Adam,Optimizer,Optimizer

# %%
#MODEL LAYERS
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization,MaxPooling2D,BatchNormalization,\
                        Permute, TimeDistributed, Bidirectional,GRU, SimpleRNN, LSTM, GlobalAveragePooling2D, SeparableConv2D
from keras import models
from keras import layers
import tensorflow as tf
from keras.applications import VGG16,VGG19,inception_v3
from keras import backend as K
from keras.utils import plot_model

# %%
#TENSORFLOW
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l2

# %%
#IGNORING WARNINGS
from warnings import filterwarnings
filterwarnings("ignore",category=DeprecationWarning)
filterwarnings("ignore", category=FutureWarning) 
filterwarnings("ignore", category=UserWarning)

# %%
Wave_Train_Path = Path(r"D:\NIT Trichy\PD_detection\wave\training")
Wave_Test_Path = Path(r"D:\NIT Trichy\PD_detection\wave\testing")
print(Wave_Train_Path)
print(Wave_Test_Path)
# Out:
# D:\NIT Trichy\PD_detection\wave\training
# D:\NIT Trichy\PD_detection\wave\testing

# %%
Wave_Train_PNG_Path = list(Wave_Train_Path.glob(r"*/*.png"))
Wave_Test_PNG_Path = list(Wave_Test_Path.glob(r"*/*.png"))
print(Wave_Train_PNG_Path)
print("---------------")
print(Wave_Test_PNG_Path)
# Out:
# [WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V01HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V01HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V02HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V02HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V03HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V03HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V04HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V04HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V05HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V05HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V06HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V06HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V07HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V07HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V08HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V08HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V09HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V09HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V10HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V10HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V11HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V11HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V12HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V12HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V12HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO04.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO05.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO06.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO07.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO12.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO13.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO14.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/healthy/V55HO15.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V01PO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V01PO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V02PO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V02PO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V03PO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V03PO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V03PO05.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V03PO06.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V03PO08.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V03PO09.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V04PO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V04PO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V05PO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V05PO03.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/training/parkinson/V06PO02.png'), WindowsPath('D:/NIT Trichy/PD_detection/wa ...
# ---------------
# [WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V01HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V02HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V03HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V04HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V05HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V06HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V07HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V08HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V09HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V10HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V11HO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V55HO08.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V55HO09.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V55HO10.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/healthy/V55HO11.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V01PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V02PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V03PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V03PO04.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V03PO07.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V04PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V05PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V06PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V07PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V08PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V09PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V10PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V11PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V14PO01.png'), WindowsPath('D:/NIT Trichy/PD_detection/wave/testing/parkinson/V14PO03.png')]

# %%
Wave_Train_PNG_Labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],Wave_Train_PNG_Path))
Wave_Test_PNG_Labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],Wave_Test_PNG_Path))
print(Wave_Train_PNG_Labels)
print("------------")
print(Wave_Test_PNG_Labels)
# Out:
# ['healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson']
# ------------
# ['healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'healthy', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson', 'parkinson']

# %%
Wave_Train_PNG_Path_Series = pd.Series(Wave_Train_PNG_Path,name="PNG").astype(str)
Wave_Train_PNG_Labels_Series = pd.Series(Wave_Train_PNG_Labels,name="CATEGORY")
print(Wave_Train_PNG_Path_Series)
print("------------")
print(Wave_Train_PNG_Labels_Series)
# Out:
# 0     D:\NIT Trichy\PD_detection\wave\training\healt...
# 1     D:\NIT Trichy\PD_detection\wave\training\healt...
# 2     D:\NIT Trichy\PD_detection\wave\training\healt...
# 3     D:\NIT Trichy\PD_detection\wave\training\healt...
# 4     D:\NIT Trichy\PD_detection\wave\training\healt...
#                             ...
# 67    D:\NIT Trichy\PD_detection\wave\training\parki...
# 68    D:\NIT Trichy\PD_detection\wave\training\parki...
# 69    D:\NIT Trichy\PD_detection\wave\training\parki...
# 70    D:\NIT Trichy\PD_detection\wave\training\parki...
# 71    D:\NIT Trichy\PD_detection\wave\training\parki...
# Name: PNG, Length: 72, dtype: object
# ------------
# 0       healthy
# 1       healthy
# 2       healthy
# 3       healthy
# 4       healthy
#         ...
# 67    parkinson
# 68    parkinson
# 69    parkinson
# 70    parkinson
# 71    parkinson
# Name: CATEGORY, Length: 72, dtype: object

# %%
Wave_Test_PNG_Path_Series = pd.Series(Wave_Test_PNG_Path,name="PNG").astype(str)
Wave_Test_PNG_Labels_Series = pd.Series(Wave_Test_PNG_Labels,name="CATEGORY")

# %%
Main_Wave_Train_Data = pd.concat([Wave_Train_PNG_Path_Series,Wave_Train_PNG_Labels_Series],axis=1)
print(Main_Wave_Train_Data)
# Out:
#                                                   PNG   CATEGORY
# 0   D:\NIT Trichy\PD_detection\wave\training\healt...    healthy
# 1   D:\NIT Trichy\PD_detection\wave\training\healt...    healthy
# 2   D:\NIT Trichy\PD_detection\wave\training\healt...    healthy
# 3   D:\NIT Trichy\PD_detection\wave\training\healt...    healthy
# 4   D:\NIT Trichy\PD_detection\wave\training\healt...    healthy
# ..                                                ...        ...
# 67  D:\NIT Trichy\PD_detection\wave\training\parki...  parkinson
# 68  D:\NIT Trichy\PD_detection\wave\training\parki...  parkinson
# 69  D:\NIT Trichy\PD_detection\wave\training\parki...  parkinson
# 70  D:\NIT Trichy\PD_detection\wave\training\parki...  parkinson
# 71  D:\NIT Trichy\PD_detection\wave\training\parki...  parkinson
#
# [72 rows x 2 columns]

# %%
Main_Wave_Test_Data = pd.concat([Wave_Test_PNG_Path_Series,Wave_Test_PNG_Labels_Series],axis=1)

# %%
Main_Wave_Train_Data = Main_Wave_Train_Data.sample(frac=1).reset_index(drop=True)
Main_Wave_Test_Data = Main_Wave_Test_Data.sample(frac=1).reset_index(drop=True)
print(Main_Wave_Test_Data)
# Out:
#                                                   PNG   CATEGORY
# 0   D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 1   D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 2   D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 3   D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 4   D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 5   D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 6   D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 7   D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 8   D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 9   D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 10  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 11  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 12  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 13  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 14  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 15  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 16  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 17  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 18  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 19  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 20  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 21  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 22  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 23  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 24  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 25  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 26  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 27  D:\NIT Trichy\PD_detection\wave\testing\parkin...  parkinson
# 28  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy
# 29  D:\NIT Trichy\PD_detection\wave\testing\health...    healthy

# %%
x_train = []
for i in range(len(Main_Wave_Train_Data)):
    img = cv2.imread(Main_Wave_Train_Data["PNG"][i])
    x_train.append(np.array(img))

# %%
x_test= []
for i in range(len(Main_Wave_Test_Data)):
    img = cv2.imread(Main_Wave_Test_Data["PNG"][i])
    x_test.append(np.array(img))

# %%
train_data_generator = ImageDataGenerator(rotation_range=5, 
                                    width_shift_range=0.1, 
                                    height_shift_range=0.1, 
                              #      brightness_range=[0.3, 1.8],
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_train)
y = list(Main_Wave_Train_Data["CATEGORY"])

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)
print(len(x_aug_train))
print(len(y_aug_train))

x_train = x + x_aug_train
y_train = y + y_aug_train
print(len(x_train))
print(len(y_train))

test_data_generator = ImageDataGenerator(rotation_range=5, 
                                    width_shift_range=0.1, 
                                    height_shift_range=0.1, 
                       #             brightness_range=[0.3, 1.8],
                                    shear_range=0.2,
                                    zoom_range=0.2,
                                    horizontal_flip=True, 
                                    vertical_flip=True)

x = list(x_test)
y = list(Main_Wave_Test_Data["CATEGORY"])

x_aug_test = []
y_aug_test = []

for (i, v) in enumerate(y):
    x_img = x[i]
    x_img = np.array(x_img)
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = test_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(20):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_test.append(aug_image)
        y_aug_test.append(v)
print(len(x_aug_test))
print(len(y_aug_test))

x_test = x + x_aug_test
y_test = y + y_aug_test
print(len(x_test))
print(len(y_test))
# Out:
# 5040
# 5040
# 5112
# 5112
# 600
# 600
# 630
# 630

# %%
# print(y_test)
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_train) if v=='healthy']
img_healthy = x_train[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Wave Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_train) if v=='parkinson']
img_parkinson = x_train[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Wave Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_healthy = [i for (i, v) in enumerate(y_test) if v=='healthy']
img_healthy = x_test[idx_healthy[-1]]
plt.imshow(img_healthy)
plt.title('Wave Drawing by a Healthy Person')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_parkinson = [i for (i, v) in enumerate(y_test) if v=='parkinson']
img_parkinson = x_test[idx_parkinson[-1]]
plt.imshow(img_parkinson)
plt.title("Wave Drawing by a Person having Parkinson's Disease")
plt.axis('off')
plt.show()

# %%
for i in range(len(x_train)):
    img = x_train[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_train[i] = img
    
for i in range(len(x_test)):
    img = x_test[i]
    img = cv2.resize(img, (128, 128))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    x_test[i] = img

x_train = np.array(x_train)
x_test = np.array(x_test)

x_train = x_train/255.0
x_test = x_test/255.0

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
print(y_train.shape)

label_encoder = LabelEncoder()
y_test = label_encoder.fit_transform(y_test)
print(y_test.shape)
# Out:
# (5112,)
# (630,)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (5112, 128, 128, 1)
# (5112, 2)
# (630, 128, 128, 1)
# (630, 2)

# %%
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))

    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))
    
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))

    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))    
    
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))
    
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 128, 128, 128)     3328
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 128)      0
#  )
#
#  conv2 (Conv2D)              (None, 40, 40, 64)        204864
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv3 (Conv2D)              (None, 12, 12, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  conv4 (Conv2D)              (None, 4, 4, 32)          9248
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  fc1 (Dense)                 (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  fc3 (Dense)                 (None, 2)                 130
#
# =================================================================
# Total params: 238,146
# Trainable params: 238,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train, y_train, batch_size=10, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 512/512 [==============================] - 84s 160ms/step - loss: 0.8209 - accuracy: 0.5223 - val_loss: 0.7990 - val_accuracy: 0.4635
# Epoch 2/70
# 512/512 [==============================] - 82s 161ms/step - loss: 0.7734 - accuracy: 0.5604 - val_loss: 0.7831 - val_accuracy: 0.4825
# Epoch 3/70
# 512/512 [==============================] - 82s 160ms/step - loss: 0.7493 - accuracy: 0.5970 - val_loss: 0.7610 - val_accuracy: 0.5937
# Epoch 4/70
# 512/512 [==============================] - 82s 160ms/step - loss: 0.7327 - accuracy: 0.6138 - val_loss: 0.7678 - val_accuracy: 0.5349
# Epoch 5/70
# 512/512 [==============================] - 81s 158ms/step - loss: 0.7120 - accuracy: 0.6334 - val_loss: 0.7379 - val_accuracy: 0.5794
# Epoch 6/70
# 512/512 [==============================] - 81s 159ms/step - loss: 0.6948 - accuracy: 0.6418 - val_loss: 0.7719 - val_accuracy: 0.5603
# Epoch 7/70
# 512/512 [==============================] - 81s 158ms/step - loss: 0.6770 - accuracy: 0.6686 - val_loss: 0.6859 - val_accuracy: 0.6444
# Epoch 8/70
# 512/512 [==============================] - 59s 115ms/step - loss: 0.6509 - accuracy: 0.6878 - val_loss: 0.6285 - val_accuracy: 0.6857
# Epoch 9/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.6177 - accuracy: 0.7207 - val_loss: 0.5977 - val_accuracy: 0.7000
# Epoch 10/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.5902 - accuracy: 0.7475 - val_loss: 0.5680 - val_accuracy: 0.7111
# Epoch 11/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.5669 - accuracy: 0.7668 - val_loss: 0.5824 - val_accuracy: 0.7349
# Epoch 12/70
# 512/512 [==============================] - 43s 84ms/step - loss: 0.5445 - accuracy: 0.7825 - val_loss: 0.5269 - val_accuracy: 0.7587
# Epoch 13/70
# 512/512 [==============================] - 43s 83ms/step - loss: 0.5419 - accuracy: 0.7895 - val_loss: 0.5588 - val_accuracy: 0.7270
# Epoch 14/70
# 512/512 [==============================] - 1494s 3s/step - loss: 0.5213 - accuracy: 0.7971 - val_loss: 0.5601 - val_accuracy: 0.7476
# Epoch 15/70
# 512/512 [==============================] - 45s 88ms/step - loss: 0.5175 - accuracy: 0.7989 - val_loss: 0.5032 - val_accuracy: 0.7730
# Epoch 16/70
# 512/512 [==============================] - 42s 81ms/step - loss: 0.5100 - accuracy: 0.8032 - val_loss: 0.7299 - val_accuracy: 0.6841
# Epoch 17/70
# 512/512 [==============================] - 44s 85ms/step - loss: 0.4940 - accuracy: 0.8128 - val_loss: 0.6108 - val_accuracy: 0.7365
# Epoch 18/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4915 - accuracy: 0.8126 - val_loss: 0.5327 - val_accuracy: 0.7762
# Epoch 19/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4893 - accuracy: 0.8214 - val_loss: 0.5145 - val_accuracy: 0.7778
# Epoch 20/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4855 - accuracy: 0.8194 - val_loss: 0.6291 - val_accuracy: 0.7333
# Epoch 21/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4770 - accuracy: 0.8236 - val_loss: 0.5437 - val_accuracy: 0.7492
# Epoch 22/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4698 - accuracy: 0.8281 - val_loss: 0.5685 - val_accuracy: 0.7603
# Epoch 23/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4723 - accuracy: 0.8281 - val_loss: 0.4978 - val_accuracy: 0.7698
# Epoch 24/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4554 - accuracy: 0.8349 - val_loss: 0.7844 - val_accuracy: 0.7063
# Epoch 25/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4640 - accuracy: 0.8290 - val_loss: 0.5663 - val_accuracy: 0.7556
# Epoch 26/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4486 - accuracy: 0.8394 - val_loss: 0.5161 - val_accuracy: 0.7873
# Epoch 27/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4552 - accuracy: 0.8365 - val_loss: 0.5552 - val_accuracy: 0.7714
# Epoch 28/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4491 - accuracy: 0.8388 - val_loss: 0.4663 - val_accuracy: 0.8000
# Epoch 29/70
# 512/512 [==============================] - 3764s 7s/step - loss: 0.4404 - accuracy: 0.8470 - val_loss: 0.5802 - val_accuracy: 0.7698
# Epoch 30/70
# 512/512 [==============================] - 46s 90ms/step - loss: 0.4443 - accuracy: 0.8414 - val_loss: 0.5160 - val_accuracy: 0.7937
# Epoch 31/70
# 512/512 [==============================] - 53s 103ms/step - loss: 0.4282 - accuracy: 0.8502 - val_loss: 0.6169 - val_accuracy: 0.7571
# Epoch 32/70
# 512/512 [==============================] - 58s 113ms/step - loss: 0.4202 - accuracy: 0.8541 - val_loss: 0.6079 - val_accuracy: 0.7730
# Epoch 33/70
# 512/512 [==============================] - 56s 109ms/step - loss: 0.4221 - accuracy: 0.8531 - val_loss: 0.8394 - val_accuracy: 0.7317
# Epoch 34/70
# 512/512 [==============================] - 56s 110ms/step - loss: 0.4181 - accuracy: 0.8566 - val_loss: 0.4884 - val_accuracy: 0.7952
# Epoch 35/70
# 512/512 [==============================] - 59s 116ms/step - loss: 0.4159 - accuracy: 0.8568 - val_loss: 0.5338 - val_accuracy: 0.7952
# Epoch 36/70
# 512/512 [==============================] - 59s 116ms/step - loss: 0.4061 - accuracy: 0.8627 - val_loss: 0.6565 - val_accuracy: 0.7619
# Epoch 37/70
# 512/512 [==============================] - 59s 116ms/step - loss: 0.4103 - accuracy: 0.8582 - val_loss: 0.6442 - val_accuracy: 0.7587
# Epoch 38/70
# 512/512 [==============================] - 59s 115ms/step - loss: 0.4072 - accuracy: 0.8615 - val_loss: 0.4623 - val_accuracy: 0.8079
# Epoch 39/70
# 512/512 [==============================] - 59s 116ms/step - loss: 0.4111 - accuracy: 0.8560 - val_loss: 0.5038 - val_accuracy: 0.8032
# Epoch 40/70
# 512/512 [==============================] - 54s 105ms/step - loss: 0.3980 - accuracy: 0.8668 - val_loss: 0.5363 - val_accuracy: 0.7968
# Epoch 41/70
# 512/512 [==============================] - 57s 110ms/step - loss: 0.3815 - accuracy: 0.8762 - val_loss: 0.4226 - val_accuracy: 0.8429
# Epoch 42/70
# 512/512 [==============================] - 55s 108ms/step - loss: 0.3783 - accuracy: 0.8799 - val_loss: 0.7404 - val_accuracy: 0.7429
# Epoch 43/70
# 512/512 [==============================] - 53s 104ms/step - loss: 0.3724 - accuracy: 0.8807 - val_loss: 0.8178 - val_accuracy: 0.7413
# Epoch 44/70
# 512/512 [==============================] - 57s 111ms/step - loss: 0.3727 - accuracy: 0.8787 - val_loss: 0.5265 - val_accuracy: 0.7968
# Epoch 45/70
# 512/512 [==============================] - 56s 110ms/step - loss: 0.3741 - accuracy: 0.8811 - val_loss: 0.4574 - val_accuracy: 0.8206
# Epoch 46/70
# 512/512 [==============================] - 54s 105ms/step - loss: 0.3877 - accuracy: 0.8689 - val_loss: 0.8092 - val_accuracy: 0.7302
# Epoch 47/70
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3554 - accuracy: 0.8895 - val_loss: 0.8103 - val_accuracy: 0.7381
# Epoch 48/70
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3501 - accuracy: 0.8934 - val_loss: 0.4636 - val_accuracy: 0.8063
# Epoch 49/70
# 512/512 [==============================] - 59s 115ms/step - loss: 0.3552 - accuracy: 0.8858 - val_loss: 0.4292 - val_accuracy: 0.8286
# Epoch 50/70
# 512/512 [==============================] - 56s 109ms/step - loss: 0.3478 - accuracy: 0.8938 - val_loss: 0.4760 - val_accuracy: 0.8254
# Epoch 51/70
# 512/512 [==============================] - 57s 112ms/step - loss: 0.3357 - accuracy: 0.8971 - val_loss: 0.4416 - val_accuracy: 0.8175
# Epoch 52/70
# 512/512 [==============================] - 57s 112ms/step - loss: 0.3336 - accuracy: 0.8977 - val_loss: 0.6042 - val_accuracy: 0.7952
# Epoch 53/70
# 512/512 [==============================] - 55s 108ms/step - loss: 0.3204 - accuracy: 0.9047 - val_loss: 0.5037 - val_accuracy: 0.8222
# Epoch 54/70
# 512/512 [==============================] - 53s 104ms/step - loss: 0.3222 - accuracy: 0.8998 - val_loss: 0.4721 - val_accuracy: 0.8254
# Epoch 55/70
# 512/512 [==============================] - 55s 107ms/step - loss: 0.3160 - accuracy: 0.9073 - val_loss: 0.4726 - val_accuracy: 0.8286
# Epoch 56/70
# 512/512 [==============================] - 55s 108ms/step - loss: 0.3151 - accuracy: 0.9075 - val_loss: 0.4618 - val_accuracy: 0.8333
# Epoch 57/70
# 512/512 [==============================] - 60s 117ms/step - loss: 0.3055 - accuracy: 0.9102 - val_loss: 0.8752 - val_accuracy: 0.7492
# Epoch 58/70
# 512/512 [==============================] - 59s 116ms/step - loss: 0.3031 - accuracy: 0.9086 - val_loss: 0.5795 - val_accuracy: 0.8111
# Epoch 59/70
# 512/512 [==============================] - 58s 113ms/step - loss: 0.2889 - accuracy: 0.9165 - val_loss: 0.5964 - val_accuracy: 0.8063
# Epoch 60/70
# 512/512 [==============================] - 59s 116ms/step - loss: 0.2979 - accuracy: 0.9153 - val_loss: 0.7351 - val_accuracy: 0.7794
# Epoch 61/70
# 512/512 [==============================] - 56s 109ms/step - loss: 0.2861 - accuracy: 0.9159 - val_loss: 0.4322 - val_accuracy: 0.8333
# Epoch 62/70
# 512/512 [==============================] - 55s 107ms/step - loss: 0.2744 - accuracy: 0.9245 - val_loss: 0.6410 - val_accuracy: 0.8048
# Epoch 63/70
# 512/512 [==============================] - 56s 110ms/step - loss: 0.2956 - accuracy: 0.9092 - val_loss: 0.4128 - val_accuracy: 0.8444
# Epoch 64/70
# 512/512 [==============================] - 58s 114ms/step - loss: 0.2754 - accuracy: 0.9249 - val_loss: 0.3885 - val_accuracy: 0.8683
# Epoch 65/70
# 512/512 [==============================] - 59s 116ms/step - loss: 0.2890 - accuracy: 0.9178 - val_loss: 0.6202 - val_accuracy: 0.8016
# Epoch 66/70
# 512/512 [==============================] - 56s 109ms/step - loss: 0.2628 - accuracy: 0.9294 - val_loss: 0.5809 - val_accuracy: 0.8190
# Epoch 67/70
# 512/512 [==============================] - 57s 112ms/step - loss: 0.2585 - accuracy: 0.9360 - val_loss: 0.6449 - val_accuracy: 0.8016
# Epoch 68/70
# 512/512 [==============================] - 61s 119ms/step - loss: 0.2477 - accuracy: 0.9353 - val_loss: 0.7161 - val_accuracy: 0.7937
# Epoch 69/70
# 512/512 [==============================] - 57s 111ms/step - loss: 0.2577 - accuracy: 0.9321 - val_loss: 0.4434 - val_accuracy: 0.8492
# Epoch 70/70
# 512/512 [==============================] - 63s 123ms/step - loss: 0.2493 - accuracy: 0.9335 - val_loss: 0.6125 - val_accuracy: 0.8127

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 20/20 [==============================] - 2s 108ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.78       315
#            1       0.75      0.95      0.84       315
#
#     accuracy                           0.81       630
#    macro avg       0.84      0.81      0.81       630
# weighted avg       0.84      0.81      0.81       630

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <AxesSubplot:>

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread(r"D:\NIT Trichy\PD_detection\wave\testing\healthy\V11HO01.png")
image_parkinson = cv2.imread(r"D:\NIT Trichy\PD_detection\wave\testing\parkinson\V09PO01.png")

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)
print(ypred_healthy)
# Out:
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 37ms/step
# [[1. 0.]]

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()

# %%
# serialize model to JSON
model_json = model.to_json()
with open("WaveModel.json", "w") as json_file:
    json_file.write(model_json)

# %%
# serialize weights to HDF5
model.save_weights("WaveModel.h5py")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.preprocessing import image
from keras.models import model_from_json
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import json
import tensorflow as tf

json_file = open('WaveModel.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("WaveModel.h5py")

print("Loaded model from disk")
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread(r"D:\NIT Trichy\PD_detection\wave\testing\healthy\V11HO01.png")
image_parkinson = cv2.imread(r"D:\NIT Trichy\PD_detection\wave\testing\parkinson\V09PO01.png")

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

ypred_healthy = loaded_model.predict(image_healthy)
ypred_parkinson = loaded_model.predict(image_parkinson)

figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
# Out:
# Loaded model from disk
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 35ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()
